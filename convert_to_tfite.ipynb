# %% [markdown]
# <a href="https://colab.research.google.com/github/InduwaraGayashan001/Neonatal-Facial-Region-Extraction/blob/main/convert_to_tfite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.4.7-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: torch<2.10,>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.9.0+cu126)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.24.0+cu126)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.31.0)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Downloading ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2026.1.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<2.10,>=1.8.0->ultralytics) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch<2.10,>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<2.10,>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<2.10,>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<2.10,>=1.8.0->ultralytics) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<2.10,>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch<2.10,>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<2.10,>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<2.10,>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<2.10,>=1.8.0->ultralytics) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<2.10,>=1.8.0->ultralytics) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<2.10,>=1.8.0->ultralytics) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<2.10,>=1.8.0->ultralytics) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<2.10,>=1.8.0->ultralytics) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<2.10,>=1.8.0->ultralytics) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<2.10,>=1.8.0->ultralytics) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<2.10,>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<2.10,>=1.8.0->ultralytics) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch<2.10,>=1.8.0->ultralytics) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<2.10,>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<2.10,>=1.8.0->ultralytics) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<2.10,>=1.8.0->ultralytics) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch<2.10,>=1.8.0->ultralytics) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<2.10,>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<2.10,>=1.8.0->ultralytics) (3.0.3)
# Downloading ultralytics-8.4.7-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 31.9 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.18-py3-none-any.whl (28 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.4.7 ultralytics-thop-2.0.18

# %%
from ultralytics import YOLO
model = YOLO("/content/best.pt")
model.export(format="tflite")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.4.7 🚀 Python-3.12.12 torch-2.9.0+cu126 CPU (Intel Xeon CPU @ 2.00GHz)
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
# YOLO11n-seg summary (fused): 113 layers, 2,834,763 parameters, 0 gradients, 9.6 GFLOPs
#
# PyTorch: starting from '/content/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) ((1, 37, 8400), (1, 32, 160, 160)) (5.7 MB)
# requirements: Ultralytics requirements ['sng4onnx>=1.0.1', 'onnx_graphsurgeon>=0.3.26', 'ai-edge-litert>=1.2.0', 'onnx>=1.12.0,<2.0.0', 'onnx2tf>=1.26.3', 'onnxslim>=0.1.71', 'onnxruntime'] not found, attempting AutoUpdate...
# Using Python 3.12.12 environment at: /usr
# Resolved 20 packages in 2.88s
# Prepared 11 packages in 1.56s
# Installed 11 packages in 439ms
#  + ai-edge-litert==2.1.0
#  + backports-strenum==1.3.1
#  + colorama==0.4.6
#  + coloredlogs==15.0.1
#  + humanfriendly==10.0
#  + onnx==1.20.1
#  + onnx-graphsurgeon==0.5.8
#  + onnx2tf==1.28.8
#  + onnxruntime==1.23.2
#  + onnxslim==0.1.82
#  + sng4onnx==1.0.4
#
# requirements: AutoUpdate success ✅ 5.5s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
#
# TensorFlow SavedModel: starting export with tensorflow 2.19.0...
#
# ONNX: starting export with onnx 1.20.1 opset 22...
# /usr/local/lib/python3.12/dist-packages/torch/onnx/_internal/torchscript_exporter/utils.py:1447: OnnxExporterWarning: Exporting to ONNX opset version 22 is not supported. by 'torch.onnx.export()'. The highest opset version supported is 20. To use a newer opset version, consider 'torch.onnx.export(..., dynamo=True)'.
#   warnings.warn(
# ONNX: slimming with onnxslim 0.1.82...
# ONNX: export success ✅ 2.0s, saved as '/content/best.onnx' (11.2 MB)
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/calibration_image_sample_data_20x128x128x3_float32.npy.zip to 'calibration_image_sample_data_20x128x128x3_float32.npy.zip': 100% ━━━━━━━━━━━━ 1.1MB 22.7MB/s 0.0s
# Unzipping calibration_image_sample_data_20x128x128x3_float32.npy.zip to /content/calibration_image_sample_data_20x128x128x3_float32.npy...: 100% ━━━━━━━━━━━━ 1/1 49.8files/s 0.0s
# TensorFlow SavedModel: starting TFLite export with onnx2tf 1.28.8...
# Saved artifact at '/content/best_saved_model'. The following endpoints are available:
#
# * Endpoint 'serving_default'
#   inputs_0 (POSITIONAL_ONLY): TensorSpec(shape=(1, 640, 640, 3), dtype=tf.float32, name='images')
# Output Type:
#   List[TensorSpec(shape=(1, 37, 8400), dtype=tf.float32, name=None), TensorSpec(shape=(1, 160, 160, 32), dtype=tf.float32, name=None)]
# Captures:
#   137538408333584: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   137538408333392: TensorSpec(shape=(3, 3, 3, 16), dtype=tf.float32, name=None)
#   137538508991824: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   137538408338192: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   137538408338576: TensorSpec(shape=(3, 3, 16, 32), dtype=tf.float32, name=None)
#   137538408337808: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   137538408338768: TensorSpec(shape=(1, 1, 32, 32), dtype=tf.float32, name=None)
#   137538408338960: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   137538408339920: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   137538408339536: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   137538408341840: TensorSpec(shape=(3, 3, 16, 8), dtype=tf.float32, name=None)
#   137538408342416: TensorSpec(shape=(8,), dtype=tf.float32, name=None)
#   137538408339152: TensorSpec(shape=(3, 3, 8, 16), dtype=tf.float32, name=None)
#   137538408335312: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   137538408340496: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   137538408340112: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   137538408342608: TensorSpec(shape=(1, 1, 48, 64), dtype=tf.float32, name=None)
#   137538408343184: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   137538408341456: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   137538408343568: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   137538408341264: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   137538408343760: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   137538408343376: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   137538408344720: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   137538408343952: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   137538408345104: TensorSpec(shape=(3, 3, 32, 16), dtype=tf.float32, name=None)
#   137538408346064: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   137538408342032: TensorSpec(shape=(3, 3, 16, 32), dtype=tf.float32, name=None)
#   137538408342800: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   137538408344144: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   137538408344528: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   137538408346256: TensorSpec(shape=(1, 1, 96, 128), dtype=tf.float32, name=None)
#   137538408342992: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   137538408346640: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   137538408345296: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   137538408346448: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   137538408346832: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   137538408347024: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   137538408347600: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   137538408347408: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   137538408349520: TensorSpec(shape=(1, 1, 64, 32), dtype=tf.float32, name=None)
#   137538408349328: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   137538408348944: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   137538408349136: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   137538408348560: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   137538408399120: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   137538408399504: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   137538408399888: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   137538408399312: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   137538408345488: TensorSpec(shape=(1, 1, 64, 32), dtype=tf.float32, name=None)
#   137538408400080: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   137538408347216: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   137538408400656: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   137538408399696: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   137538408347792: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   137538408347984: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   137538408400848: TensorSpec(shape=(1, 1, 192, 128), dtype=tf.float32, name=None)
#   137538408401040: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   137538408401232: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   137538408400272: TensorSpec(shape=(3, 3, 128, 256), dtype=tf.float32, name=None)
#   137538408400464: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   137538408401616: TensorSpec(shape=(1, 1, 256, 256), dtype=tf.float32, name=None)
#   137538408401808: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   137538408402384: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   137538408402192: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   137538408404304: TensorSpec(shape=(1, 1, 128, 64), dtype=tf.float32, name=None)
#   137538408404496: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   137538408403728: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   137538408404688: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   137538408404880: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   